# %% [markdown]
# ## Michaud Model Sweep

# %%
import pde_sweep as ps
import michaud

ps.sweep(michaud.run,
        "michaud_params.json", # Path to JSON file containing parameters
        ["k0", "k1", "k2", "k3", "k4", "k5", "k6", "k7", "k8", "k9", "k10","Drt", "Drd", "Df", "sigma", "s", "f", "alpha", "beta"], # Parameters to sweep
        [2.0, 5.0, 10.0], # Factors
        "michaud_sweep" # Output directory
        )
