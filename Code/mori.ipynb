# %% [markdown]
# ## Mori Model
#
# (2.1) from Hughes et al. 2024
#
# $\frac{\partial u}{\partial t}=(b+\gamma\frac{u^n}{1+u^n})v-Iu+D\frac{\partial^2u}{\partial x^2}$
#
# $\frac{\partial v}{\partial t}=-(b+\gamma\frac{u^n}{1+u^n})v+Iu+\frac{\partial^2v}{\partial x^2}$

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from matplotlib.animation import PillowWriter
from pde_utils import double_derivative

# define parameters
Da = 0.1 # A diffusion rate
Db = 10 # B diffusion rate
delta = 1 # basal rate of inactivation
gamma = 1.0 # GTPase autocatalytic activation rate
K = 1 # saturation parameter
k0 = 0.067 # basal GEF conversion rate
L = 10 # cell diameter (µm)

size = 100 # number of cells
dx = L / size
dt = 0.01  # time step
t = 200.0 # run time
frame_int = 5 # animation frame interval

# set up figure
fig, ax = plt.subplots(figsize=(8, 4))
frames = []

# set initial concentrations
A =  2 * 0.2683312 * np.random.rand(size)
B = np.full(size, 2.0)

# define reaction kinetics function
def f(a, b):
    return (k0 + gamma*a**2/(K**2 + a**2))*b - delta*a

# simulate the PDE with finite difference method
for i in range(int(t/dt)):

    # update concentrations
    A = A + dt * (Da * double_derivative(A, dx) + f(A, B))
    A = B + dt * (Db * double_derivative(B, dx) - f(A, B))

    # apply Neumann boundary conditions
    for Z in (A, B):
        Z[0] = Z[1]
        Z[-1] = Z[-2]

    # capture a frame every frame_int seconds
    if i % int(frame_int/dt) == 0:
        Aline, = ax.plot(A, color='blue')
        frames.append([Aline])

# save animation
animation.ArtistAnimation(fig, frames, interval=50, blit=True).save('animations/mori.gif', writer=PillowWriter(fps=10))
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/t3/rvfzpmc50v9bpqnjwzlzbb1w0000gp/T/ipykernel_87002/1294418817.py in <module>
# ----> 1 import numpy as np
#       2 import matplotlib.pyplot as plt
#       3 import matplotlib.animation as animation
#       4 from matplotlib.animation import PillowWriter
#       5 from pde_utils import double_derivative
#
# ModuleNotFoundError: No module named 'numpy'
